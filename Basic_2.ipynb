# %% [markdown]
# <a href="https://colab.research.google.com/github/princevp2006-source/synent-task2-DataVisualization-prince/blob/main/Basic_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('iris.csv')
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print("Bar chart:")
plt.figure(figsize=(6,5))
sns.countplot(x='species',data=df)
plt.title('Count Of Iris Species')
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()
# Out:
# Bar chart:

# %%
plt.figure(figsize=(6,5))
plt.hist(df['sepal_length'],bins=10)
plt.title("Distribution of Sepal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,5))

sns.scatterplot(
    x='sepal_length',
    y='petal_length',
    hue='species',
    data=df
)

plt.title("Sepal Length vs Petal Length")

plt.show()

# %%
plt.figure(figsize=(8,6))

sns.boxplot(x='species', y='petal_length', data=df)

plt.title("Petal Length Comparison Among Species")

plt.show()
